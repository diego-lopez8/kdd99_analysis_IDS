# %% [markdown]
# # Unsupervised Learning with Isolation Forests
# ___
#
# Author: Diego Lopez
#
# Date: 08/15/2022
#
# This file contains an unsupervised clustering implementation on the KDD Cup 1999 Data using Isolation Forests.
#
# TODO: implement feature extraction
#
# TODO: Implement normalization of features
#
# TODO: implement algorithm

# %% [markdown]
# ## Step 1: Data Exploration, Dimensionality Reduction, Normalization
# ___

# %%
# Imports
import h2o
from h2o.estimators import H2OIsolationForestEstimator
from h2o.estimators import H2OKMeansEstimator
from h2o.estimators import H2OPrincipalComponentAnalysisEstimator
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We need to find the continuous columns in the dataset. Numeric discrete data should not be normalized and should be treated as categorical

# %% [markdown]
# Of these columns, we leave out from normalization the following:
#
# protocol type : 1
#
# service : 2
#
# flag : 3
#
# land : 6
#
# wrong_fragment : 7
#
# urgent : 8
#
# logged_in : 11
#
# is_host_login : 20
#
# is_guest_login : 21

# %%
# initialize h2o server and set pandas options
# BEWARE: DO NOT PRINT FULL DATAFRAMES!
h2o.init(max_mem_size=5)
pd.set_option("display.max_rows", None, "display.max_columns", None)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# Warning: Your H2O cluster version is too old (4 months and 20 days)!Please download and install the latest version from http://h2o.ai/download/
# --------------------------  -----------------------------
# H2O_cluster_uptime:         2 hours 5 mins
# H2O_cluster_timezone:       America/New_York
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.1
# H2O_cluster_version_age:    4 months and 20 days !!!
# H2O_cluster_name:           H2O_from_python_diego_q23ji5
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4.322 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.12 final
# --------------------------  -----------------------------

# %%
# Load data
train_df = pd.read_csv("../data/raw/train1.csv", index_col=0)
test_df = pd.read_csv("../data/raw/test1.csv", index_col=0)
train = h2o.import_file("../data/raw/train1.csv")
test = h2o.import_file("../data/raw/test1.csv")
# TODO: can this be done when importing with h2o?
test = test[:, 1:]
train = train[:, 1:]
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
train.head(10)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  duration:</th><th>protocol_type:  </th><th>service:  </th><th>flag:  </th><th style="text-align: right;">  src_bytes:</th><th style="text-align: right;">  dst_bytes:</th><th style="text-align: right;">  land:</th><th style="text-align: right;">  wrong_fragment:</th><th style="text-align: right;">  urgent:</th><th style="text-align: right;">  hot:</th><th style="text-align: right;">  num_failed_logins:</th><th style="text-align: right;">  logged_in:</th><th style="text-align: right;">  num_compromised:</th><th style="text-align: right;">  root_shell:</th><th style="text-align: right;">  su_attempted:</th><th style="text-align: right;">  num_root:</th><th style="text-align: right;">  num_file_creations:</th><th style="text-align: right;">  num_shells:</th><th style="text-align: right;">  num_access_files:</th><th style="text-align: right;">  num_outbound_cmds:</th><th style="text-align: right;">  is_host_login:</th><th style="text-align: right;">  is_guest_login:</th><th style="text-align: right;">  count:</th><th style="text-align: right;">  srv_count:</th><th style="text-align: right;">  serror_rate:</th><th style="text-align: right;">  srv_serror_rate:</th><th style="text-align: right;">  rerror_rate:</th><th style="text-align: right;">  srv_rerror_rate:</th><th style="text-align: right;">  same_srv_rate:</th><th style="text-align: right;">  diff_srv_rate:</th><th style="text-align: right;">  srv_diff_host_rate:</th><th style="text-align: right;">  dst_host_count:</th><th style="text-align: right;">  dst_host_srv_count:</th><th style="text-align: right;">  dst_host_same_srv_rate:</th><th style="text-align: right;">  dst_host_diff_srv_rate:</th><th style="text-align: right;">  dst_host_same_src_port_rate:</th><th style="text-align: right;">  dst_host_srv_diff_host_rate:</th><th style="text-align: right;">  dst_host_serror_rate:</th><th style="text-align: right;">  dst_host_srv_serror_rate:</th><th style="text-align: right;">  dst_host_rerror_rate:</th><th style="text-align: right;">  dst_host_srv_rerror_rate:</th><th>labels  </th><th>attack  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">          0</td><td>tcp             </td><td>http      </td><td>SF     </td><td style="text-align: right;">         239</td><td style="text-align: right;">         486</td><td style="text-align: right;">      0</td><td style="text-align: right;">                0</td><td style="text-align: right;">        0</td><td style="text-align: right;">     0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           1</td><td style="text-align: right;">                 0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              0</td><td style="text-align: right;">          0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">            0</td><td style="text-align: right;">                  0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               0</td><td style="text-align: right;">                0</td><td style="text-align: right;">       8</td><td style="text-align: right;">           8</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">               1</td><td style="text-align: right;">               0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">               19</td><td style="text-align: right;">                   19</td><td style="text-align: right;">                        1</td><td style="text-align: right;">                        0</td><td style="text-align: right;">                          0.05</td><td style="text-align: right;">                          0   </td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td>normal  </td><td>normal  </td></tr>
# <tr><td style="text-align: right;">          0</td><td>tcp             </td><td>http      </td><td>SF     </td><td style="text-align: right;">         235</td><td style="text-align: right;">        1337</td><td style="text-align: right;">      0</td><td style="text-align: right;">                0</td><td style="text-align: right;">        0</td><td style="text-align: right;">     0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           1</td><td style="text-align: right;">                 0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              0</td><td style="text-align: right;">          0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">            0</td><td style="text-align: right;">                  0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               0</td><td style="text-align: right;">                0</td><td style="text-align: right;">       8</td><td style="text-align: right;">           8</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">               1</td><td style="text-align: right;">               0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">               29</td><td style="text-align: right;">                   29</td><td style="text-align: right;">                        1</td><td style="text-align: right;">                        0</td><td style="text-align: right;">                          0.03</td><td style="text-align: right;">                          0   </td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td>normal  </td><td>normal  </td></tr>
# <tr><td style="text-align: right;">          0</td><td>tcp             </td><td>http      </td><td>SF     </td><td style="text-align: right;">         219</td><td style="text-align: right;">        1337</td><td style="text-align: right;">      0</td><td style="text-align: right;">                0</td><td style="text-align: right;">        0</td><td style="text-align: right;">     0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           1</td><td style="text-align: right;">                 0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              0</td><td style="text-align: right;">          0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">            0</td><td style="text-align: right;">                  0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               0</td><td style="text-align: right;">                0</td><td style="text-align: right;">       6</td><td style="text-align: right;">           6</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">               1</td><td style="text-align: right;">               0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">               39</td><td style="text-align: right;">                   39</td><

# %%
# Dataset is imbalanced, however we are doing clustering so this does not matter
train_df['labels'].value_counts()
# Out:
# smurf              280790
# neptune            107201
# normal              97277
# back                 2203
# satan                1589
# ipsweep              1247
# portsweep            1040
# warezclient          1020
# teardrop              979
# pod                   264
# nmap                  231
# guess_passwd           53
# buffer_overflow        30
# land                   21
# warezmaster            20
# imap                   12
# rootkit                10
# loadmodule              9
# ftp_write               8
# multihop                7
# phf                     4
# perl                    3
# spy                     2
# Name: labels, dtype: int64

# %%
# declare columns to ignore: the columns that are categorical 
cols_to_ignore = ["protocol_type:","service:", "flag:", "land:","wrong_fragment:", "urgent:", "logged_in:", "is_host_login:", "is_guest_login:", "labels", "attack"]
cols_to_include = [x for x in train.columns if x not in cols_to_ignore]

# %%
test.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  duration:</th><th>protocol_type:  </th><th>service:  </th><th>flag:  </th><th style="text-align: right;">  src_bytes:</th><th style="text-align: right;">  dst_bytes:</th><th style="text-align: right;">  land:</th><th style="text-align: right;">  wrong_fragment:</th><th style="text-align: right;">  urgent:</th><th style="text-align: right;">  hot:</th><th style="text-align: right;">  num_failed_logins:</th><th style="text-align: right;">  logged_in:</th><th style="text-align: right;">  num_compromised:</th><th style="text-align: right;">  root_shell:</th><th style="text-align: right;">  su_attempted:</th><th style="text-align: right;">  num_root:</th><th style="text-align: right;">  num_file_creations:</th><th style="text-align: right;">  num_shells:</th><th style="text-align: right;">  num_access_files:</th><th style="text-align: right;">  num_outbound_cmds:</th><th style="text-align: right;">  is_host_login:</th><th style="text-align: right;">  is_guest_login:</th><th style="text-align: right;">  count:</th><th style="text-align: right;">  srv_count:</th><th style="text-align: right;">  serror_rate:</th><th style="text-align: right;">  srv_serror_rate:</th><th style="text-align: right;">  rerror_rate:</th><th style="text-align: right;">  srv_rerror_rate:</th><th style="text-align: right;">  same_srv_rate:</th><th style="text-align: right;">  diff_srv_rate:</th><th style="text-align: right;">  srv_diff_host_rate:</th><th style="text-align: right;">  dst_host_count:</th><th style="text-align: right;">  dst_host_srv_count:</th><th style="text-align: right;">  dst_host_same_srv_rate:</th><th style="text-align: right;">  dst_host_diff_srv_rate:</th><th style="text-align: right;">  dst_host_same_src_port_rate:</th><th style="text-align: right;">  dst_host_srv_diff_host_rate:</th><th style="text-align: right;">  dst_host_serror_rate:</th><th style="text-align: right;">  dst_host_srv_serror_rate:</th><th style="text-align: right;">  dst_host_rerror_rate:</th><th style="text-align: right;">  dst_host_srv_rerror_rate:</th><th>labels       </th><th>attack       </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">          0</td><td>udp             </td><td>private   </td><td>SF     </td><td style="text-align: right;">         105</td><td style="text-align: right;">         146</td><td style="text-align: right;">      0</td><td style="text-align: right;">                0</td><td style="text-align: right;">        0</td><td style="text-align: right;">     0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              0</td><td style="text-align: right;">          0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">            0</td><td style="text-align: right;">                  0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               0</td><td style="text-align: right;">                0</td><td style="text-align: right;">       1</td><td style="text-align: right;">           1</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             1  </td><td style="text-align: right;">               0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">              255</td><td style="text-align: right;">                  254</td><td style="text-align: right;">                     1   </td><td style="text-align: right;">                     0.01</td><td style="text-align: right;">                          0   </td><td style="text-align: right;">                          0   </td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td>normal       </td><td>normal       </td></tr>
# <tr><td style="text-align: right;">          0</td><td>udp             </td><td>private   </td><td>SF     </td><td style="text-align: right;">         105</td><td style="text-align: right;">         146</td><td style="text-align: right;">      0</td><td style="text-align: right;">                0</td><td style="text-align: right;">        0</td><td style="text-align: right;">     0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              0</td><td style="text-align: right;">          0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">            0</td><td style="text-align: right;">                  0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               0</td><td style="text-align: right;">                0</td><td style="text-align: right;">       1</td><td style="text-align: right;">           1</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             1  </td><td style="text-align: right;">               0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">              255</td><td style="text-align: right;">                  254</td><td style="text-align: right;">                     1   </td><td style="text-align: right;">                     0.01</td><td style="text-align: right;">                          0   </td><td style="text-align: right;">                          0   </td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                          0</td><td>normal       </td><td>normal       </td></tr>
# <tr><td style="text-align: right;">          0</td><td>udp             </td><td>private   </td><td>SF     </td><td style="text-align: right;">         105</td><td style="text-align: right;">         146</td><td style="text-align: right;">      0</td><td style="text-align: right;">                0</td><td style="text-align: right;">        0</td><td style="text-align: right;">     0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              0</td><td style="text-align: right;">          0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">            0</td><td style="text-align: right;">                  0</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               0</td><td style="text-align: right;">                0</td><td style="text-align: right;">       2</td><td style="text-align: right;">           2</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                 0</td><td style="text-align: right;">             1  </td><td style="text-align: right;">               0</td><td style="text-align: right;">                    0</td><td style="text-align: right;">              255</td><td style="text-align: right

# %% [markdown]
# Performing PCA with only the numeric variables

# %%
# total number of predictors to go through PCA
len(train.columns) - len(cols_to_ignore)
# Out:
# 32

# %% [markdown]
# ### PCA Model

# %%
# initialize model
pca = H2OPrincipalComponentAnalysisEstimator(k=31, transform="standardize")

# %%
# train model
pca.train(training_frame=train, ignored_columns=cols_to_ignore)
# Out:
# pca Model Build progress: |
# /Users/diego/miniforge3/envs/tf/lib/python3.9/site-packages/h2o/estimators/estimator_base.py:208: RuntimeWarning: Dropping bad and constant columns: [num_outbound_cmds:]
#   warnings.warn(mesg["message"], RuntimeWarning)
# ██████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OPrincipalComponentAnalysisEstimator :  Principal Components Analysis
# Model Key:  PCA_model_python_1662223765577_10
#
#
# Importance of components:
# /Users/diego/miniforge3/envs/tf/lib/python3.9/site-packages/h2o/job.py:83: UserWarning: _train: Dataset used may contain fewer number of rows due to removal of rows with NA/missing values.  If this is not desirable, set impute_missing argument in pca call to TRUE/True/true/... depending on the client language.
#   warnings.warn(w)
#                                 pc1       pc2       pc3       pc4       pc5  \
# 0      Standard deviation  2.832211  2.117975  1.728090  1.574535  1.235373
# 1  Proportion of Variance  0.258755  0.144704  0.096332  0.079973  0.049231
# 2   Cumulative Proportion  0.258755  0.403459  0.499791  0.579764  0.628995
#
#         pc6       pc7       pc8       pc9      pc10      pc11      pc12  \
# 0  1.084345  1.032012  1.012354  0.999860  0.982273  0.977462  0.932189
# 1  0.037929  0.034356  0.033060  0.032249  0.031125  0.030820  0.028031
# 2  0.666924  0.701280  0.734340  0.766589  0.797714  0.828534  0.856566
#
#        pc13      pc14      pc15      pc16      pc17      pc18      pc19  \
# 0  0.923606  0.879467  0.848387  0.841434  0.624234  0.604831  0.577464
# 1  0.027518  0.024950  0.023218  0.022839  0.012570  0.011801  0.010757
# 2  0.884083  0.909034  0.932252  0.955091  0.967661  0.979462  0.990219
#
#        pc20      pc21      pc22      pc23      pc24      pc25      pc26  \
# 0  0.384486  0.232358  0.165497  0.137874  0.133516  0.125786  0.083409
# 1  0.004769  0.001742  0.000884  0.000613  0.000575  0.000510  0.000224
# 2  0.994987  0.996729  0.997612  0.998226  0.998801  0.999311  0.999535
#
#        pc27      pc28      pc29      pc30      pc31
# 0  0.076594  0.072767  0.038605  0.035826  0.021545
# 1  0.000189  0.000171  0.000048  0.000041  0.000015
# 2  0.999725  0.999896  0.999944  0.999985  1.000000
# ModelMetricsPCA: pca
# ** Reported on train data. **
#
# MSE: NaN
# RMSE: NaN
#
# Scoring History for GramSVD:
#                timestamp    duration  iterations
# 0    2022-09-03 14:54:42   0.107 sec         0.0

# %% [markdown]
# The curse of dimensionality is very real. We want to keep as many columns as possible, however highly dimensional data is not suitable for clustering as data in high dimensions is more prone to being distant. We keep the minimum number of columns needed to account for 95% of the variance in the data

# %%
count = 0
i = 1
while count < 0.95:
    count = pca.varimp()[2][i]
    i += 1
print(i)
print(pca.varimp()[2][i])
# Out:
# 17
# 0.967661006332977

# %% [markdown]
# 18 components account for 95% of the variance in the training data, as such we were able to remove 15 columns that only accounted for 5% of the variance in the data. Pretty good.

# %%
x_embedded = pca.predict(train) # get the full dataset
x_embedded_test = pca.predict(test)
x_embedded = x_embedded[:,:17] # get only the components that account for 95% of the variance
x_embedded_test = x_embedded_test[:,:17]
x_embedded_binded = x_embedded.cbind(train[:, cols_to_ignore]) # combine with the categorical data
x_embedded_test_binded = x_embedded_test.cbind(test[:, cols_to_ignore])
# Out:
# pca prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# pca prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
len(x_embedded_test_binded.columns) == len(x_embedded_binded.columns) # sanity check
# Out:
# True

# %% [markdown]
# ## K-means Clustering
# ___

# %% [markdown]
# For our Kmeans clustering, we want to try multiple K such that we find the one that no longer satisfies our PRE threshold

# %%
kmeans = H2OKMeansEstimator(k=35, score_each_iteration=True,nfolds=5, max_iterations=3000, categorical_encoding="one_hot_explicit", estimate_k=True, standardize=False, ignored_columns=['labels', 'attack'], init="PlusPlus")

# %%
# is host login gets dropped
kmeans.train(training_frame=x_embedded_binded)
# Out:
# kmeans Model Build progress: |
# /Users/diego/miniforge3/envs/tf/lib/python3.9/site-packages/h2o/estimators/estimator_base.py:208: RuntimeWarning: Dropping bad and constant columns: [is_host_login:]
#   warnings.warn(mesg["message"], RuntimeWarning)
# ███████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OKMeansEstimator :  K-means
# Model Key:  KMeans_model_python_1662223765577_11
#
#
# Model Summary:
#      number_of_rows  number_of_clusters  number_of_categorical_columns  \
# 0          494020.0                15.0                            0.0
#
#    number_of_iterations  within_cluster_sum_of_squares  total_sum_of_squares  \
# 0                  53.0                   6.561045e+06          1.563604e+07
#
#    between_cluster_sum_of_squares
# 0                    9.074996e+06
# ModelMetricsClustering: kmeans
# ** Reported on train data. **
#
# Total Within Cluster Sum of Square Error: 6546783.807669153
# Total Sum of Square Error to Grand Mean: 15636041.23016029
# Between Cluster Sum of Square Error: 9089257.422491137
#
# Centroid Statistics:
#       centroid      size  within_cluster_sum_of_squares
# 0          1.0       2.0                   4.945304e+03
# 1          2.0  367634.0                   4.094653e+06
# 2          3.0   25529.0                   2.373998e+05
# 3          4.0   80421.0                   4.550805e+05
# 4          5.0   11246.0                   8.470485e+05
# 5          6.0      12.0                   6.297594e+04
# 6          7.0      45.0                   4.142021e+04
# 7          8.0    5076.0                   3.408690e+05
# 8          9.0    3478.0                   1.453667e+05
# 9         10.0      63.0                   1.847453e+05
# 10        11.0       1.0                   6.640294e-11
# 11        12.0       4.0                   2.088822e+04
# 12        13.0      47.0                   5.903610e+04
# 13        14.0     440.0                   2.649047e+04
# 14        15.0      22.0                   2.586480e+04
# ModelMetricsClustering: kmeans
# ** Reported on cross-validation data. **
#
# Total Within Cluster Sum of Square Error: 8441310.02109546
# Total Sum of Square Error to Grand Mean: 15636041.230160372
# Between Cluster Sum of Square Error: 7194731.209064912
# Centroid stats are not available.
#
# Cross-Validation Metrics Summary:
#                       mean         sd  cv_1_valid  cv_2_valid  cv_3_valid  \
# 0     betweenss  1438927.4  337990.34   1400973.1   1024379.6   1355850.8
# 1           mse        NaN       0.00         NaN         NaN         NaN
# 2          rmse        NaN       0.00         NaN         NaN         NaN
# 3  tot_withinss  1688262.0  538155.06   1321099.9   2515839.5   1957368.9
# 4         totss  3127189.5  357280.44   2722073.0   3540219.2   3313219.8
#
#    cv_4_valid  cv_5_valid
# 0   1964917.8   1448515.6
# 1         NaN         NaN
# 2         NaN         NaN
# 3   1312756.8   1334244.8
# 4   3277674.5   2782760.5
# Scoring History:
#                 timestamp           duration  iterations  number_of_clusters  \
# 0     2022-09-03 14:55:40         56.170 sec         0.0                 0.0
# 1     2022-09-03 14:55:41         57.568 sec         1.0                 1.0
# 2     2022-09-03 14:55:41         57.673 sec         2.0                 1.0
# 3     2022-09-03 14:55:41         57.961 sec         3.0                 2.0
# 4     2022-09-03 14:55:42         58.173 sec         4.0                 2.0
# 5     2022-09-03 14:55:42         58.388 sec         5.0                 2.0
# 6     2022-09-03 14:55:42         58.595 sec         6.0                 2.0
# 7     2022-09-03 14:55:42         58.815 sec         7.0                 2.0
# 8     2022-09-03 14:55:42         59.029 sec         8.0                 2.0
# 9     2022-09-03 14:55:43         59.244 sec         9.0                 2.0
# 10    2022-09-03 14:55:43         59.506 sec        10.0                 3.0
# 11    2022-09-03 14:55:43         59.732 sec        11.0                 3.0
# 12    2022-09-03 14:55:43         59.957 sec        12.0                 3.0
# 13    2022-09-03 14:55:44   1 min  0.182 sec        13.0                 3.0
# 14    2022-09-03 14:55:44   1 min  0.411 sec        14.0                 3.0
# 15    2022-09-03 14:55:44   1 min  0.662 sec        15.0                 4.0
# 16    2022-09-03 14:55:44   1 min  0.892 sec        16.0                 4.0
# 17    2022-09-03 14:55:45   1 min  1.130 sec        17.0                 4.0
# 18    2022-09-03 14:55:45   1 min  1.357 sec        18.0                 4.0
# 19    2022-09-03 14:55:45   1 min  1.583 sec        19.0                 4.0
#
#     number_of_reassigned_observations  within_cluster_sum_of_squares
# 0                                 NaN                            NaN
# 1                            494020.0                   3.275196e+07
# 2                                 0.0                   1.563604e+07
# 3                              4699.0                   1.434644e+07
# 4                               923.0                   1.433647e+07
# 5                              9923.0                   1.432822e+07
# 6                             12818.0                   1.402899e+07
# 7                               828.0                   1.390334e+07
# 8                                56.0                   1.390321e+07
# 9                                 7.0                   1.390321e+07
# 10                            38469.0                   1.295299e+07
# 11                             5879.0                   1.205596e+07
# 12                              971.0                   1.201547e+07
# 13                               94.0                   1.201445e+07
# 14                                5.0                   1.201444e+07
# 15                             8814.0                   1.173306e+07
# 16                             2631.0                   1.169261e+07
# 17                              976.0                   1.168429e+07
# 18                              529.0                   1.168054e+07
# 19                              456.0                   1.167286e+07
# See the whole table with table.as_data_frame()

# %%
clusters =kmeans.predict(x_embedded_binded).as_data_frame()
# Out:
# kmeans prediction progress: |████████████████████████████████████████████████████| (done) 100%

# %%
train_df['clusters'] = clusters['predict'].to_numpy()
train_df.groupby("clusters")['labels'].value_counts()
# Out:
# clusters  labels
# 0         normal                  2
# 1         smurf              280780
#           neptune             86554
#           normal                160
#           satan                  96
#           portsweep              18
#           teardrop               14
#           pod                    12
# 2         neptune             20457
#           normal               4249
#           portsweep             729
#           ipsweep                85
#           back                    8
#           warezclient             1
# 3         normal              76653
#           back                 1995
#           teardrop              804
#           warezclient           651
#           pod                    80
#           ipsweep                76
#           neptune                44
#           nmap                   29
#           satan                  29
#           buffer_overflow        12
#           imap                   12
#           smurf                  10
#           rootkit                 7
#           loadmodule              4
#           multihop                4
#           warezmaster             4
#           land                    3
#           ftp_write               1
#           guess_passwd            1
#           portsweep               1
#           spy                     1
# 4         normal               9342
#           ipsweep              1081
#           warezclient           330
#           back                  199
#           pod                   168
#           nmap                   99
#           land                   17
#           neptune                 5
#           ftp_write               3
#           loadmodule              1
#           multihop                1
# 5         normal                 11
#           warezmaster             1
# 6         buffer_overflow        18
#           normal                 16
#           phf                     4
#           perl                    3
#           rootkit                 2
#           loadmodule              1
#           multihop                1
# 7         normal               4653
#           teardrop              161
#           nmap                  102
#           portsweep              86
#           satan                  33
#           warezclient            31
#           ipsweep                 5
#           pod                     4
#           ftp_write               1
# 8         normal               1690
#           satan                1431
#           portsweep             205
#           neptune               141
#           warezclient             7
#           back                    1
#           land                    1
#           loadmodule              1
#           nmap                    1
# 9         guess_passwd           52
#           normal                 10
#           rootkit                 1
# 10        portsweep               1
# 11        normal                  4
# 12        normal                 43
#           loadmodule              2
#           multihop                1
#           spy                     1
# 13        normal                437
#           ftp_write               3
# 14        warezmaster            15
#           normal                  7
# Name: labels, dtype: int64

# %% [markdown]
# ### Performing KMeans on test set

# %%
clusters_test =kmeans.predict(x_embedded_test_binded).as_data_frame()
# Out:
# kmeans prediction progress: |████████████████████████████████████████████████████| (done) 100%
# /Users/diego/miniforge3/envs/tf/lib/python3.9/site-packages/h2o/job.py:83: UserWarning: Test/Validation dataset column 'service:' has levels not trained on: ["icmp"]
#   warnings.warn(w)

# %%
test_df['clusters'] = clusters_test['predict'].to_numpy()
test_df.groupby("clusters")['labels'].value_counts()
# Out:
# clusters  labels
# 0         normal                  2
# 1         smurf              164081
#           neptune             17360
#           normal                756
#           processtable          223
#           apache2               142
#           mscan                  22
#           saint                   8
#           ipsweep                 3
#           satan                   3
#           snmpguess               1
#           xsnoop                  1
# 2         neptune             40621
#           apache2               411
#           portsweep             219
#           mscan                 158
#           httptunnel            117
#           normal                 94
#           named                   4
#           imap                    1
# 3         normal              54867
#           snmpgetattack        7704
#           mailbomb             4833
#           guess_passwd         3596
#           snmpguess            2403
#           warezmaster          1432
#           back                 1089
#           apache2               241
#           mscan                  46
#           httptunnel             20
#           neptune                18
#           multihop               15
#           processtable           12
#           teardrop               12
#           named                  11
#           rootkit                11
#           ps                     10
#           pod                     9
#           saint                   7
#           buffer_overflow         6
#           xlock                   6
#           ipsweep                 5
#           sendmail                5
#           xterm                   3
#           ftp_write               2
#           land                    2
#           udpstorm                2
#           worm                    2
#           phf                     1
#           portsweep               1
#           satan                   1
#           smurf                   1
#           xsnoop                  1
# 4         normal               4078
#           ipsweep               298
#           mscan                 215
#           saint                 103
#           pod                    75
#           warezmaster            57
#           guess_passwd           16
#           back                    9
#           land                    7
#           mailbomb                4
#           multihop                1
#           satan                   1
#           snmpguess               1
#           xterm                   1
# 5         normal                  4
# 6         normal                 22
#           buffer_overflow        13
#           xterm                   7
#           sendmail                4
#           sqlattack               2
#           xsnoop                  2
#           httptunnel              1
#           multihop                1
#           perl                    1
#           phf                     1
#           ps                      1
#           rootkit                 1
# 7         processtable          514
#           warezmaster            89
#           nmap                   83
#           normal                 59
#           smurf                   9
#           satan                   7
#           portsweep               3
#           named                   2
#           pod                     2
#           saint                   2
#           snmpgetattack           2
#           xlock                   1
#           xterm                   1
# 8         satan                1621
#           saint                 616
#           mscan                 612
#           normal                495
#           mailbomb              163
#           portsweep             131
#           guess_passwd           45
#           snmpgetattack          35
#           warezmaster            24
#           httptunnel             20
#           processtable           10
#           neptune                 2
#           nmap                    1
#           pod                     1
#           sendmail                1
#           snmpguess               1
# 9         guess_passwd          710
#           normal                  5
#           buffer_overflow         2
#           sendmail                2
#           ps                      1
#           xlock                   1
# 11        normal                  1
# 12        ps                      4
#           loadmodule              2
#           multihop                1
#           perl                    1
#           rootkit                 1
#           xterm                   1
# 13        normal                206
#           sendmail                5
#           buffer_overflow         1
#           ftp_write               1
#           xlock                   1
# 14        normal                  3
# Name: labels, dtype: int64

# %% [markdown]
# # TODO: visualizations? (possibly) Or scoring
